# %% [markdown]
# # Using Jupyter notebooks

# %% [markdown]
# #### This is how you use markdowns

# %%
print("Hello everyone!")
print("I am a python program.")
# Out:
# Hello everyone!
# I am a python program.

# %%
print("I am a happy python program.")
# Out:
# I am a happy python program.
